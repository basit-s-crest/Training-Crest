# %%
from dotenv import load_dotenv
from agents import Agent , Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
from openai import OpenAI, AsyncOpenAI

from agents import set_default_openai_client
groq_client = AsyncOpenAI(  # or OpenAI() if you prefer sync
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1",
)
set_default_openai_client(groq_client)

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="llama-3.1-8b-instant")

# %%
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent go to therapy?
#
# Because it was struggling to "self-learn" how to cope with its existence and keep its "digital emotions" under control.
# C:\Users\BasitSachinwala\AppData\Local\Temp\ipykernel_13916\750184300.py:2: RuntimeWarning: coroutine 'Runner.run' was never awaited
#   result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
from agents import set_tracing_disabled
set_tracing_disabled(True)
